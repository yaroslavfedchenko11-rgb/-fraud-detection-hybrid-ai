# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('../data/insurance_claims.csv', na_values=['?'])
df = df.drop(columns=['_c39'])  # лишний пустой столбец из экспорта
df.shape
# Out:
# (1000, 39)
